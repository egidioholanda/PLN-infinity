# %% [markdown]
# <a href="https://colab.research.google.com/github/egidioholanda/PLN-infinity/blob/main/AnaliseDeSentimentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/natorjunior/debates-ideologicos/main/dataset.csv"
)

# %%
df
# Out:
#                                                    Text  Label
# 0     diego freitas e a jovem pobre q mora no morro ...      1
# 1     moral e algo pessoal não tente enfiar seus val...      1
# 2     eu acho engraçado que se posicionar sobre o út...      1
# 3     adriano barboza da mesma forma como vc demonst...      1
# 4     a vida termina qnd acaba atividade cerebral en...      1
# ...                                                 ...    ...
# 1765  e assustador ver pessoas defendendo a eugenia ...      0
# 1766  no dia em que a medicina conseguir descobrir q...      0
# 1767  tenho minhas ideias sobre o aborto não sou rel...      0
# 1768  melhor comentario leia e difícil entender a ta...      0
# 1769  aborto mesmo tirando o lado religioso e uma qu...      0
#
# [1770 rows x 2 columns]

# %%
df["Label"].value_counts()
# Out:
# 0    993
# 1    777
# Name: Label, dtype: int64

# %%
df["Label"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
import plotly.express as px

# %%
px.bar(x=df.Label.value_counts().values)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
txt = ''.join(df['Text'].values)

# %%
txt
# Out:
# 'diego freitas e a jovem pobre q mora no morro sem instrução e a criança q vai nascer e viver em pessimas condições e cair na criminalidade e facil falar sobre proibição do aborto qundo se e homem de classe mediamoral e algo pessoal não tente enfiar seus valores morais em outra pessoa isso não existe sou a favor da legalização do aborto não sou a favor do aborto isso e uma escolha da mulher afinal quem paga o pato depois somos nós mesmas não e quem quer abortar vai abortar sendo legal ou não e quem não quer abortar não vai fazer sendo legal ou não ou vocêa acham que com a legalização do aborto vão ter comerciais na tv falando e aí ta sem nada pra fazer vamos fazer um abortinhoeu acho engraçado que se posicionar sobre o útero alheio e mto facil se homem engravidasse aborto ja era legalizado falar que e feio crime e bla bla bla e facil pílula do dia seguinte falha camisinha estoura diu sai do lugar e um monte de outras coisas acontecem são adversidades enfiar criança no orfanato tmbm n
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
text = txt
# Gerando a nuvem de palavras
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(text)
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %%
df_zero = df.query('Label == 0')

# %%
df_um = df.query('Label == 1')

# %%
txt_0 = ''.join(df_zero['Text'].values)

# %%
txt_0
# Out:
# 'quando não se deseja gravidez usa se preservativos contraceptivos pilula do dia seguinte boa parte delas entregues gratuitamente pelo sus e se comprados custam imensamente menos que criar filhos ainda ha a pratica da adoção da criança indesejada não ha gravidez indesejada ha sim irresponsabilidade praticada partindo da premissa que se faz com o próprio corpo o quer que bem deseje e que nunca pode ou deve ser endossada com a cruel e perversa possibilidade de matar o feto outro corpomas como funcionara isso na pratica num país onde não ha educação sexual nas escolas nem em casa as meninas de irão abortar todos os meses ou tera uma cota para as madames ate funcionara mas pra camada mais pobre da população vai virar um caos tal qual a pílula do dia seguinte em que meninas tomam sem nenhum controle como se este fosse um metodo contraceptivo conheço varias meninas que ja recorreram a tal procedimento por mais de uma vez no mêso aborto causa mais traumas físicos e sequelas que um parto não
# ...

# %%
txt_1 = ''.join(df_um['Text'].values)

# %%
txt_1
# Out:
# 'diego freitas e a jovem pobre q mora no morro sem instrução e a criança q vai nascer e viver em pessimas condições e cair na criminalidade e facil falar sobre proibição do aborto qundo se e homem de classe mediamoral e algo pessoal não tente enfiar seus valores morais em outra pessoa isso não existe sou a favor da legalização do aborto não sou a favor do aborto isso e uma escolha da mulher afinal quem paga o pato depois somos nós mesmas não e quem quer abortar vai abortar sendo legal ou não e quem não quer abortar não vai fazer sendo legal ou não ou vocêa acham que com a legalização do aborto vão ter comerciais na tv falando e aí ta sem nada pra fazer vamos fazer um abortinhoeu acho engraçado que se posicionar sobre o útero alheio e mto facil se homem engravidasse aborto ja era legalizado falar que e feio crime e bla bla bla e facil pílula do dia seguinte falha camisinha estoura diu sai do lugar e um monte de outras coisas acontecem são adversidades enfiar criança no orfanato tmbm n
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
text = txt_1
# Gerando a nuvem de palavras
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(text)
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
text = txt_0
# Gerando a nuvem de palavras
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(text)
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
